# %% [markdown]
# <a href="https://colab.research.google.com/github/tetrarahat/ACM-ICPC-Preparation/blob/master/Week_01_Setup_Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import sklearn

print ("Hello AI Journey!")
print (f"Numpy version: {np.__version__}")
print (f"Pandas version: {pd.__version__}")
print(f"Scikit-learn version: {sklearn.__version__}")
# Out:
# Hello AI Journey!
# Numpy version: 2.0.2
# Pandas version: 2.2.2
# Scikit-learn version: 1.6.1
